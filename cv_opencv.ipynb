# %% [markdown]
# <a href="https://colab.research.google.com/github/HARRY-hussein/computer_vision/blob/main/cv_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
import cv2
image = cv2.imread("/content/cat_image.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=720x719>

# %%
print("SHAPE:", image.shape)
# 2571 => height
# 3840 => width
# 3 => color channels (BGR) => Blue, Green, Red
print("HEIGHT:",image.shape[0])
print("WIDTH:",image.shape[1])
print("CHANNELS:", image.shape[2])
# Out:
# SHAPE: (719, 720, 3)
# HEIGHT: 719
# WIDTH: 720
# CHANNELS: 3

# %%
(b, g, r) = image[100, 50] #rasmdagi 100-qator va 50-ustundagi ranglarni ko'rsatyapti
print("Blue:", b, "Green:", g, "Red:", r)
# Out:
# Blue: 31 Green: 31 Red: 19

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=720x719>

# %%
resized = cv2.resize(gray,(300,300))
cv2_imshow(resized)

# %%
cropped = image[100:1700, 350:1800]
cv2_imshow(cropped)

# %%
rotated = cv2.rotate(gray, cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2_imshow(rotated)

# %%
flipped = cv2.flip(gray, 1)
cv2_imshow(flipped)

# %%
cv2.imwrite("cropped_cat.jpg", cropped)

# %%
cropped_cat = cv2.imread("/content/cropped_cat.jpg")
cv2_imshow(cropped_cat)

# %%
import os

for f in os.listdir():
    if f.endswith(".ipynb"):
        size = os.path.getsize(f) / (1024 * 1024)
        print(f"{f}: {size:.2f} MB")

# %% [markdown]
# Opencv video streaming codes

# %%
import cv2
print("Hello world")

cap = cv2.VideoCapture(0)

face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

while True:
    success, frame = cap.read()

    if not success:
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.1, 4)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    cv2.imshow("Real-time Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()


# ========================================================
# import cv2
# print("Hello world")

# url = "rstp://192.168.1.164:8001/video" # stream_path

# cap = cv2.VideoCapture(url)

# while True:
#     success, frame = cap.read()  # True, False | Boolean

#     if not success:
#         break
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

#     blurred = cv2.GaussianBlur(frame, (15, 15), 0)
#     edges1 = cv2.Canny(frame, 100, 200)
#     edges2 = cv2.Canny(frame, 100, 200)
#     flipped = cv2.flip(frame, 1)

#     cv2.imshow("Original", frame)
#     # cv2.imshow("Gray", gray)
#     # cv2.imshow("Blurred", blurred)  # Noise
#     # cv2.imshow("edge1", edges1)
#     # cv2.imshow("edge2", edges2)
#     cv2.imshow("Flipped", flipped)

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()
# Out:
# Hello world
